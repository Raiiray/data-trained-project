# %% [markdown]
# # Baseball Case Study

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("baseball.csv")

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# # Problem statement
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# Output: Number of predicted wins (W)

# %% [markdown]
# H – Hit: reaching base because of a batted, fair ball without error by the defense
# 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error
# 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
# AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
# HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
# R – Runs scored: number of times a player crosses home plate
# SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense
# BB – Base on balls (also called a "walk"): times pitching four balls, allowing the batter to take first base
# CG – Complete game: number of games where player was the only pitcher for their team
# ER – Earned run: number of runs that did not occur as a result of errors or passed balls
# ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
# RA – Run average: number of runs allowed times nine divided by innings pitched
# SHO – Shutout: number of complete games pitched with no runs allowed
# SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings
# W – Win: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work (also related: winning percentage)

# %%
sns.pairplot(df)

# %% [markdown]
# From above pair plot we can see relation between various variables . In the next part we will be doing univariate ,bivariate and multi variate analysis for better understanding.

# %%
df["CG"].value_counts()
# Out:
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df["W"] , y=df["R"] ,hue=df["CG"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %% [markdown]
# here we can see there is a positive relation between R and W. and we can clearly see that no of completed games is also higher for higher no of wins.

# %%
sns.scatterplot(x=df["W"] , y=df["2B"] ,hue=df["CG"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='2B'>

# %% [markdown]
# here we can see there is a positive relation between 2B and W. and we can clearly see that no of completed games is also higher for higher no of wins.

# %%
sns.scatterplot(x=df["2B"] , y=df["3B"] ,hue=df["CG"])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='3B'>

# %%
sns.scatterplot(x=df["W"] , y=df["HR"] ,hue=df["CG"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='HR'>

# %% [markdown]
# here we can see there is a positive relation between HR and W. and we can clearly see that no of completed games is also higher for higher no of wins.

# %%
sns.scatterplot(x=df["W"] , y=df["BB"] ,hue=df["CG"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='BB'>

# %% [markdown]
# here we can see there is a positive relation between BB and W. and we can clearly see that no of completed games is also higher for higher no of wins.

# %%
sns.scatterplot(x=df["W"] , y=df["SO"] ,hue=df["CG"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='SO'>

# %% [markdown]
# We can clearly see that no of completed games is also higher for higher no of wins.But there is no such relation between SOand W.

# %%
sns.scatterplot(x=df["W"] , y=df["RA"] ,hue=df["CG"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='RA'>

# %% [markdown]
# here we can see there is a negetive relation between RA and W. and we can clearly see that no of completed games is also higher for higher no of wins.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df["W"] , y=df["ER"] ,hue=df["CG"],style=df["SHO"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='ER'>

# %% [markdown]
# here we can see there is a negetive relation between ER and W. and we can clearly see that no of completed games is also higher for higher no of wins.Maximum no of SHO is 10 , then 12 and then 13.

# %%
sns.scatterplot(x=df["W"] , y=df["ERA"] ,hue=df["CG"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='ERA'>

# %% [markdown]
# here we can see there is a negetive relation between ERA and W. and we can clearly see that no of completed games is also higher for higher no of wins.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df["W"] ,y=df["SV"]  ,hue=df["CG"] ,style=df["SHO"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %% [markdown]
# here we can see there is a positive relation between SV and W. and we can clearly see that no of completed games is also higher for higher no of wins.Maximum no of SHO is 10 , then 12 and then 13.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df["W"] ,y=df["E"]  ,hue=df["CG"] ,style=df["SHO"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='E'>

# %% [markdown]
# We can clearly see that no of completed games is also higher for higher no of wins.But there is no such relation between SOand W.We can clearly see that no of completed games is also higher for higher no of wins.Maximum no of SHO is 10 , then 12 and then 13.

# %%
df["SHO"].value_counts()
# Out:
# 12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: SHO, dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# from the above heatmapwe can see that no missing value is there in thedataset.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# from the statistical description we can see that not much differences are there in between 75% and max values and in between mean and 50% . So there is a less chance of having much skewness in the data but still if can find some skew ness we will remove that .

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# here we can see that there is not much skewness present in the data set but forbetter result we will remove this skewness also.

# %%
import scipy
from scipy.stats import zscore

# %%
z= np.abs(zscore(df))
print(z)
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# Here we have applied Z score method to remove outliers . In the next step we will calculate the percentage data loss.

# %%
df.shape
# Out:
# (30, 17)

# %%
dataloss=(1/30)*100
dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# after removing outliers we can see that data loss percentage is not so much , so we are going for the next step that is splitting of data into input variable and output variable.

# %%
x=df_new.drop(["W"],axis=1)
y=df_new["W"]
print(x.shape)
print(y.shape)
# Out:
# (29, 16)
# (29,)

# %%
from sklearn.preprocessing import power_transform
xt=power_transform(x, method="yeo-johnson")
xt=pd.DataFrame(xt)
xt.columns = x.columns
xt
# Out:
#            R   AB    H        2B        3B        HR        BB        SO  \
# 0   0.962544  0.0  0.0  1.685188  1.006150 -0.741927 -1.605198 -2.550612
# 1   0.298863  0.0  0.0  0.138198  1.185227 -0.109958 -0.462096  0.093683
# 2  -0.312105  0.0  0.0  1.907385 -0.228819 -0.664354  1.232098 -0.935611
# 3  -1.308298  0.0  0.0 -0.837665 -0.432228 -0.860039 -1.162721 -0.230683
# 4   0.137737  0.0  0.0  0.911435  1.622636 -0.289647 -0.155686  0.044143
# 5   1.964209  0.0  0.0 -0.163010 -1.295827  1.631637  1.579494 -0.269583
# 6   0.698146  0.0  0.0 -1.542635 -1.182758  1.767734 -0.877217  0.770980
# 7  -0.852595  0.0  0.0  0.199897  0.068703  0.269125 -0.520476  0.556008
# 8   1.555951  0.0  0.0  1.255256  0.166017  0.065014  0.270944 -1.019210
# 9   1.631727  0.0  0.0  0.262086  0.068703  0.434620  0.717576 -0.211199
# 10  1.084297  0.0  0.0  0.199897 -0.535590  2.109761  0.415731  1.409203
# 11 -0.487692  0.0  0.0 -1.682709 -1.071323  0.564164 -0.540002 -1.000673
# ...

# %% [markdown]
# here we have applied yeo jhonson method for removing the skewness.

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(xt):
    vif = pd.DataFrame()
    vif["variables"] = xt.columns
    vif["V_I_F"] = [variance_inflation_factor(xt.values,i) for i in range(xt.shape[1])]
    return(vif)

# %%
calvif=calc_vif(xt)
print(calvif)
calvif["V_I_F"].sort_values(ascending=False)
# Out:
#    variables     V_I_F
# 0          R  3.705587
# 1         AB       NaN
# 2          H       NaN
# 3         2B  2.428417
# 4         3B  2.853692
# 5         HR  4.373979
# 6         BB  2.681863
# 7         SO  2.240742
# 8         SB  1.654468
# 9         RA  3.837591
# 10        CG  1.914839
# 11       SHO  2.843322
# 12        SV  2.267888
# 13         E  1.358427
# 5     4.373979
# 9     3.837591
# 0     3.705587
# 4     2.853692
# 11    2.843322
# 6     2.681863
# 3     2.428417
# 12    2.267888
# 7     2.240742
# 10    1.914839
# 8     1.654468
# 13    1.358427
# 1          NaN
# 2          NaN
# Name: V_I_F, dtype: float64

# %% [markdown]
# here we are checking multicolinearity and for having the most vif value we have decided to drop hr column.

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df_new.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# here we can see the co relation between various columns , here we can see that RA , ER,ERA these collumns are highly co related with each other so wehave to drop ER,ERA columns too for better result.

# %%
xt.drop(["ER" , "ERA" ,"HR"],axis=1,inplace=True)
xt

# %%
xt.drop(["HR"],axis=1,inplace=True)
xt
# Out:
#            R   AB    H        2B        3B        BB        SO        SB  \
# 0   0.962544  0.0  0.0  1.685188  1.006150 -1.605198 -2.550612  0.936132
# 1   0.298863  0.0  0.0  0.138198  1.185227 -0.462096  0.093683 -0.516377
# 2  -0.312105  0.0  0.0  1.907385 -0.228819  1.232098 -0.935611  0.225038
# 3  -1.308298  0.0  0.0 -0.837665 -0.432228 -1.162721 -0.230683 -0.618422
# 4   0.137737  0.0  0.0  0.911435  1.622636 -0.155686  0.044143  0.095038
# 5   1.964209  0.0  0.0 -0.163010 -1.295827  1.579494 -0.269583 -0.884526
# 6   0.698146  0.0  0.0 -1.542635 -1.182758 -0.877217  0.770980 -2.082843
# 7  -0.852595  0.0  0.0  0.199897  0.068703 -0.520476  0.556008  0.267558
# 8   1.555951  0.0  0.0  1.255256  0.166017  0.270944 -1.019210 -0.466233
# 9   1.631727  0.0  0.0  0.262086  0.068703  0.717576 -0.211199  0.824915
# 10  1.084297  0.0  0.0  0.199897 -0.535590  0.415731  1.409203  1.521413
# 11 -0.487692  0.0  0.0 -1.682709 -1.071323 -0.540002 -1.000673 -1.535760
# ...

# %%
calvif=calc_vif(xt)
print(calvif)
# Out:
#    variables     V_I_F
# 0          R  1.531042
# 1         AB       NaN
# 2          H       NaN
# 3         2B  2.142007
# 4         3B  2.692125
# 5         BB  2.650856
# 6         SO  1.384507
# 7         SB  1.614179
# 8         RA  3.819838
# 9         CG  1.819737
# 10       SHO  2.809265
# 11        SV  2.266056
# 12         E  1.212449

# %% [markdown]
# now we can see there is not much colinearity present in the data set .

# %%
x.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
xt.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# from the above boxplots we can clearly compare the box plots that after removing outliers and before removing outliers.

# %%
for col in xt.columns:
    plt.figure(figsize=(10,4))
    plt.subplot(121)
    sns.distplot(xt[col])
    plt.title(col)
    
    plt.subplot(122)
    sns.distplot(x[col])
    plt.title(col)

# %% [markdown]
# here also we can compare the distplots before removing skewness and afer remving skewness.

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xc=sc.fit_transform(xt)
xc=pd.DataFrame(xc)
xc.columns=xt.columns
xc
# Out:
#            R   AB    H        2B        3B        BB        SO        SB  \
# 0   0.962544  0.0  0.0  1.685188  1.006150 -1.605198 -2.550612  0.936132
# 1   0.298863  0.0  0.0  0.138198  1.185227 -0.462096  0.093683 -0.516377
# 2  -0.312105  0.0  0.0  1.907385 -0.228819  1.232098 -0.935611  0.225038
# 3  -1.308298  0.0  0.0 -0.837665 -0.432228 -1.162721 -0.230683 -0.618422
# 4   0.137737  0.0  0.0  0.911435  1.622636 -0.155686  0.044143  0.095038
# 5   1.964209  0.0  0.0 -0.163010 -1.295827  1.579494 -0.269583 -0.884526
# 6   0.698146  0.0  0.0 -1.542635 -1.182758 -0.877217  0.770980 -2.082843
# 7  -0.852595  0.0  0.0  0.199897  0.068703 -0.520476  0.556008  0.267558
# 8   1.555951  0.0  0.0  1.255256  0.166017  0.270944 -1.019210 -0.466233
# 9   1.631727  0.0  0.0  0.262086  0.068703  0.717576 -0.211199  0.824915
# 10  1.084297  0.0  0.0  0.199897 -0.535590  0.415731  1.409203  1.521413
# 11 -0.487692  0.0  0.0 -1.682709 -1.071323 -0.540002 -1.000673 -1.535760
# ...

# %% [markdown]
# here we have appliedstandard scaler for scaling the data .

# %%
xc.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
import sklearn
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error , mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
maxacc=0
maxrs=0
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(xc,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    acc=lr.score(x_train,y_train)
    if acc > maxacc:
        maxacc=acc
        maxrs=i
print("best accuracy score is",maxacc,"on random state",maxrs)
# Out:
# best accuracy score is 0.9813223091589788 on random state 71

# %%
x_train,x_test,y_train,y_test=train_test_split(xc,y,test_size=0.2,random_state=71)
lr=LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print(lr.score(x_train,y_train))
print(r2_score(y_test,predlr))
# Out:
# 0.9813223091589788
# -2.218448544034508

# %%
score=cross_val_score(lr,xc,y,cv=5)
score.mean()
# Out:
# 0.3290364073289372

# %%
maxacc=0
maxrs=0
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(xc,y,test_size=0.2,random_state=i)
    dtr=DecisionTreeRegressor()
    dtr.fit(x_train,y_train)
    pred=dtr.predict(x_test)
    acc=dtr.score(x_train,y_train)
    if acc > maxacc:
        maxacc=acc
        maxrs=i
print("best accuracy score is",maxacc,"on random state",maxrs)
# Out:
# best accuracy score is 1.0 on random state 0

# %%
x_train,x_test,y_train,y_test=train_test_split(xc,y,test_size=0.2,random_state=0)
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=dtr.predict(x_test)
print(dtr.score(x_train,y_train))
print(r2_score(y_test,pred))
# Out:
# 1.0
# -1.1299093655589125

# %%
score=cross_val_score(dtr,xc,y,cv=5)
score.mean()
# Out:
# -2.6648398003536635

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.model_selection import GridSearchCV
rd = Ridge()
ls= Lasso()
parameters = {"alpha" : [0.0001,0.001,0.01,0.1]}

# %%
gscvr=GridSearchCV(Ridge(),parameters,cv=5)

# %%
gscvr.fit(xc,y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1]})

# %%
gscvr.best_params_
# Out:
# {'alpha': 0.1}

# %%
gscvr.best_estimator_
# Out:
# Ridge(alpha=0.1)

# %%
gscvrpred=gscvr.best_estimator_.predict(x_test)

# %%
print(r2_score(y_test,gscvrpred))
print(mean_squared_error(y_test,gscvrpred))
# Out:
# 0.9065676216840637
# 6.8724704939055385

# %%
score=cross_val_score(gscvr,xc,y,cv=5)
score.mean()
# Out:
# 0.3407652724521527

# %%
gscvl=GridSearchCV(Lasso(),parameters,cv=5)
gscvl.fit(xc,y)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1]})

# %%
gscvlpred=gscvl.best_estimator_.predict(x_test)
print(r2_score(y_test,gscvlpred))
print(mean_squared_error(y_test,gscvlpred))
# Out:
# 0.9130058812983526
# 6.398900731165617

# %%
score=cross_val_score(gscvl,xc,y,cv=5)
score.mean()
# Out:
# 0.4051370068436454

# %% [markdown]
# as it is a regression model here we have applied various regression models . but due to overfitting the models are not giving good results , so we have applied regularisation techniques , lasso and ridge regression , among these two lasso regression has given the best result so we have decided to go with lasso regression.

# %%
import joblib
joblib.dump(gscvl.best_estimator_,"baseball.pkl")
# Out:
# ['baseball.pkl']
